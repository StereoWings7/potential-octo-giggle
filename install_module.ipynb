# %% [markdown]
# <a href="https://colab.research.google.com/github/StereoWings7/potential-octo-giggle/blob/main/install_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
#このセルは、ColabのWeb GUIからGoogle Driveをマウントする場合は必要なし
 from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#(*)パッケージをインストールする先のディレクトリを指定する。
package_path = '/content/drive/MyDrive/Colab\ Notebooks/my-site-packages/'
package_path_str = '/content/drive/MyDrive/Colab Notebooks/my-site-packages/'

# %%
# pipを最新版にアップグレード(しないと後のインストールでコケる可能性がある)
# !pip install --upgrade pip

# %%
#必要なパッケージをpipからインストールする。インストール先はGoogle Driveに指定する。
# !pip install d2l==1.0.3 -t $package_path
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 86.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 96.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 111.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 71.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 93.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 106.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 115.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 92.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 820.8/820.8 kB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 108.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.6 MB/s eta 0:00:00
# ...

# %%
#d2lがインストールされたか確認
os.chdir('/content/drive/MyDrive/Colab Notebooks/my-site-packages/d2l/')
os.listdir()
# Out:
# ['tensorflow.py',
#  'mxnet.py',
#  'torch.py',
#  '__pycache__',
#  'jax.py',
#  '__init__.py']

# %%
#一度Google Driveへのインストールが完了したら、次回からは↑の(*)を実行してから↓2つのセルを実行するだけでOK
#インポートするモジュールを探索する先のディレクトリに、今パッケージをインストールしたディレクトリを追加してやる。
import sys
sys.path.append(package_path_str)

# %%
#あとは普通にインポートするだけ。
import d2l
from d2l import torch as d2l
